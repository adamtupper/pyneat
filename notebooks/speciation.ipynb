# %% [markdown]
# ## Investigating Speciation
#
# Analyse the results of the speciation parameter grid search on the initial and final populations of Pong experiment #4.

# %%
import pandas as pd

# %%
df = pd.read_csv('../../notebooks/speciation_grid_search_results_asteroids_a.csv')
df.head()
# Out:
#    generation  threshold  disjoint_coeff  weight_coeff  n_species
# 0           0        3.0             1.0           0.4          1
# 1          75        3.0             1.0           0.4          1
# 2           0        3.0             1.0           0.5          1
# 3          75        3.0             1.0           0.5          1
# 4           0        3.0             1.0           0.6          1

# %%
conditions = ['(10 < n_species < 125)',
              '(weight_coeff > 0)',
              '(disjoint_coeff > 0)']
df.query(str.join('&', conditions))
# Out:
#      generation  threshold  disjoint_coeff  weight_coeff  n_species
# 20            0        3.0             1.0           1.2         50
# 23            0        3.0             1.0           1.3        119
# 55           75        3.0             1.0           3.3         20
# 60           75        3.0             1.0           3.4         23
# 79            0        3.0             1.5           1.0         72
# 81            0        3.0             1.5           1.1        124
# 115          75        3.0             1.5           3.2         12
# 117          75        3.0             1.5           3.3         21
# 124          75        3.0             1.5           3.4         23
# 131           0        3.0             2.0           0.7         15
# 137           0        3.0             2.0           0.8         85
# 176          75        3.0             2.0           3.2         12
# 180          75        3.0             2.0           3.3         21
# ...

# %%
conditions = ['(10 < n_species < 125)',
              '(weight_coeff >= 1)',
              '(disjoint_coeff >= 1)',
              '(weight_coeff > disjoint_coeff)']
df.query(str.join('&', conditions))
# Out:
#      generation  threshold  disjoint_coeff  weight_coeff  n_species
# 20            0        3.0             1.0           1.2         50
# 23            0        3.0             1.0           1.3        119
# 55           75        3.0             1.0           3.3         20
# 60           75        3.0             1.0           3.4         23
# 115          75        3.0             1.5           3.2         12
# 117          75        3.0             1.5           3.3         21
# 124          75        3.0             1.5           3.4         23
# 176          75        3.0             2.0           3.2         12
# 180          75        3.0             2.0           3.3         21
# 184          75        3.0             2.0           3.4         23
# 237          75        3.0             2.5           3.1         11
# 240          75        3.0             2.5           3.2         12
# 242          75        3.0             2.5           3.3         21
# ...
